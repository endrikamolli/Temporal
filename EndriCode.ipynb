# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = {
    'datetime': pd.date_range(start="2020-01-01", periods=500, freq='D'),
    'cnt': np.random.randint(100, 1000, size=500),
    'season': np.random.choice([1, 2, 3, 4], size=500)
}

# %%
df = pd.DataFrame(data)

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df.set_index('datetime', inplace=True)

# %%
st.title("Bike Ridership Analysis")
# Out:
# 2025-05-06 15:36:59.837 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:36:59.989
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-05-06 15:36:59.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.header("Total Ridership Over Time")
fig, ax = plt.subplots()
ax.plot(df.index, df['cnt'], label="Total Ridership")
ax.set_xlabel("Date")
ax.set_ylabel("Ridership Count")
ax.set_title("Total Ridership Over Time")
ax.legend()
st.pyplot(fig)
# Out:
# 2025-05-06 15:37:18.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:37:18.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:37:18.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:37:19.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:37:19.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.header("Total Ridership by Season")
season_ridership = df.groupby('season')['cnt'].sum()
season_labels = {1: 'Winter', 2: 'Spring', 3: 'Summer', 4: 'Fall'}
season_ridership.index = season_ridership.index.map(season_labels)
fig, ax = plt.subplots()
season_ridership.plot(kind='bar', ax=ax)
ax.set_xlabel("Season")
ax.set_ylabel("Total Ridership")
ax.set_title("Total Ridership by Season")
st.pyplot(fig)
# Out:
# 2025-05-06 15:37:26.344 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:37:26.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:37:26.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:37:26.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:37:26.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.header("Rolling Average of Total Ridership")
rolling_option = st.radio(
    "Select Rolling Average Option:",
    ('7-day average', '14-day average', 'Total ridership by week')
)
# Out:
# 2025-05-06 15:37:35.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:37:35.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:37:35.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:37:35.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:37:35.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:37:35.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:37:35.193 Session state does not function when running a script without `streamlit run`
# 2025-05-06 15:37:35.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:37:35.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if rolling_option == '7-day average':
    df['7_day_avg'] = df['cnt'].rolling(window=7).mean()
    fig, ax = plt.subplots()
    ax.plot(df.index, df['7_day_avg'], label="7-Day Rolling Average", color='orange')
    ax.set_xlabel("Date")
    ax.set_ylabel("Rolling Average Ridership")
    ax.set_title("7-Day Rolling Average of Total Ridership")
    ax.legend()
    st.pyplot(fig)
# Out:
# 2025-05-06 15:48:33.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:48:34.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:48:34.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if __name__ == "__main__":
    st.write("Explore the visualizations above!")
# Out:
# 2025-05-06 15:49:30.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-06 15:49:30.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
